# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in C:\Users\navan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (3.0.2)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\navan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pandas) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\navan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\navan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in C:\Users\navan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: C:\Users\navan\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
import pandas as pd
df=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],columns=["A","B","C"], index=["x","y","z"])
df.head() # we can flow a index inside the head(" ") to get the value from 0th index to till passed
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
df.tail(2) # we can flow a index inside the Tail(" ") to get the value from last index to till passed in reverse
# Out:
#    A  B  C
# y  4  5  6
# z  7  8  9

# %%
df.columns  # displays colums and the dtype of the variables in column
# Out:
# Index(['A', 'B', 'C'], dtype='str')

# %%
df.index  # displays rows and the dtype of the variables in row
# Out:
# Index(['x', 'y', 'z'], dtype='str')

# %%
x=df.index.tolist()  # we can represent as list by using tolist 
y=df.columns.tolist()
print(x)
print(y)
# Out:
# ['x', 'y', 'z']
# ['A', 'B', 'C']

# %%
df.info()   # displays the info of an dataframe
# Out:
# <class 'pandas.DataFrame'>
# Index: 3 entries, x to z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 99.0 bytes

# %%
df.describe()  # gives the info about the values with there respected percentages
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df.shape # diaplys the shape of an DataFrame (rows,columns)
# Out:
# (3, 3)

# %%
df.size   # size of an DataFrame
# Out:
# 9

# %% [markdown]
# LOADING DATASETS

# %%
coffee=pd.read_csv('../data/coffee.csv')
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
results=pd.read_parquet('../data/results.parquet', engine='fastparquet')

# %%
results.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None
# 4           1  FRA  Jacques Brugnon    4.0  False  None

# %%
olympics_data=pd.read_excel('../data/olympics-data.xlsx')

# %%
olympics_data.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios=pd.read_csv('../data/bios.csv')

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %% [markdown]
# ACCESSING DATA WITH PANDAS

# %%
coffee.head(10)
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35
# 5  Wednesday       Latte          25
# 6   Thursday    Espresso          40
# 7   Thursday       Latte          30
# 8     Friday    Espresso          45
# 9     Friday       Latte          35

# %%
coffee.tail(5)
# Out:
#          Day Coffee Type  Units Sold
# 9     Friday       Latte          35
# 10  Saturday    Espresso          45
# 11  Saturday       Latte          35
# 12    Sunday    Espresso          45
# 13    Sunday       Latte          35

# %%
coffee.sample(10) # randomly select the data among dataset in the csv file
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 4   Wednesday    Espresso          35
# 10   Saturday    Espresso          45
# 6    Thursday    Espresso          40
# 9      Friday       Latte          35
# 12     Sunday    Espresso          45
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 13     Sunday       Latte          35
# 0      Monday    Espresso          25

# %%
coffee.loc[[1,7]] # we can select the data by using loc and passing the index of the data we want to select
# Out:
#         Day Coffee Type  Units Sold
# 1    Monday       Latte          15
# 7  Thursday       Latte          30

# %%
coffee.loc[5:10] # we can use slicing to retrieve the data from index ranges
# Out:
#           Day Coffee Type  Units Sold
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45

# %%
coffee.loc[5:9,["Day","Units Sold"]] # we can use slicing to retrieve the data from index ranges and also we can pass the column name to get the specific column data
# Out:
#          Day  Units Sold
# 5  Wednesday          25
# 6   Thursday          40
# 7   Thursday          30
# 8     Friday          45
# 9     Friday          35

# %%
coffee.iloc[:,[0,2]] # [[selective rows index],[selective column index]]
# Out:
#           Day  Units Sold
# 0      Monday          25
# 1      Monday          15
# 2     Tuesday          30
# 3     Tuesday          20
# 4   Wednesday          35
# 5   Wednesday          25
# 6    Thursday          40
# 7    Thursday          30
# 8      Friday          45
# 9      Friday          35
# 10   Saturday          45
# 11   Saturday          35
# 12     Sunday          45
# 13     Sunday          35

# %%
# we can modify the data by using loc and iloc and passing the index of the data we want to modify and also we can pass the column name to get the specific column data and then we can assign the new value to it
coffee.loc[1,"Units Sold"]=20
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1         25       Latte          20
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
# at-> gives an single value based on the reqiured index and column name
coffee.at[1,"Units Sold"]
# Out:
# np.int64(20)

# %%
# iat-> gives an single value based on the reqiured index and column index
coffee.iat[0,1]
# Out:
# 'Espresso'

# %%
coffee.sort_values(["Units Sold","Coffee Type"], ascending=True) # we can sort the values by using sort_values and passing the column name and also we can pass the ascending as False to sort in descending order
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          15
# 3     Tuesday       Latte          20
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
for index,row in coffee.iterrows():
    print(row['Units Sold'])
    print(index)
    print("\n")
# Out:
# 25
# 0
#
#
# 15
# 1
#
#
# 30
# 2
#
#
# 20
# 3
#
#
# 35
# 4
#
#
# 25
# 5
#
#
# 40
# 6
#
#
# 30
# 7
#
#
# 45
# 8
#
#
# 35
# 9
#
#
# 45
# 10
#
#
# 35
# 11
#
#
# 45
# 12
#
#
# 35
# 13

# %% [markdown]
# FILTERING DATA

# %%
bios.tail()
# Out:
#         athlete_id                 name   born_date        born_city  \
# 145495      149222    Polina Luchnikova  2002-01-30            Serov
# 145496      149223  Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224      Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225       André Foussard  1899-05-19            Niort
# 145499      149814        Bill Phillips  1913-07-15     Dulwich Hill
#
#             born_region born_country        NOC  height_cm  weight_kg  \
# 145495       Sverdlovsk          RUS        ROC      167.0       61.0
# 145496           Moskva          RUS        ROC      168.0       65.0
# 145497      Arkhangelsk          RUS        ROC      163.0       55.0
# 145498      Deux-Sèvres          FRA     France      166.0        NaN
# 145499  New South Wales          AUS  Australia        NaN        NaN
#
#          died_date
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498  1986-03-18
# 145499  2003-10-20

# %%
bios.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  str
#  2   born_date     143693 non-null  str
#  3   born_city     110908 non-null  str
#  4   born_region   110908 non-null  str
#  5   born_country  110908 non-null  str
#  6   NOC           145499 non-null  str
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   str
# dtypes: float64(2), int64(1), str(7)
# memory usage: 18.5 MB

# %%
bios.loc[bios['height_cm']>215,['name','height_cm']]   # we can display data based on certain constraints and conditions
# Out:
#                          name  height_cm
# 5089       Viktor Pankrashkin      220.0
# 5583     Paulinho Villas Boas      217.0
# 5673           Gunther Behnke      221.0
# 5716                 Uwe Blab      218.0
# 5781           Tommy Burleson      223.0
# 5796            Andy Campbell      218.0
# 6223              Lars Hansen      216.0
# 6270              Hu Zhangbao      216.0
# 6409         Sergey Kovalenko      216.0
# 6420            Jānis Krūmiņš      218.0
# 6504              Luc Longley      220.0
# 6722         Shaquille O'Neal      216.0
# 6937           David Robinson      216.0
# 6978          Arvydas Sabonis      223.0
# 7074           Paulo da Silva      217.0
# 7188       Vladimir Tkachenko      220.0
# 7281         Stojko Vranković      217.0
# 7376      Eurelijus Žukauskas      218.0
# 52608         Aleksey Kazakov      217.0
# 82100           Frédéric Weis      218.0
# 89070                Yao Ming      226.0
# 89075          Roberto Dueñas      221.0
# 107408       Peter John Ramos      219.0
# 112312           Stanko Barać      217.0
# 112332    Andreas Glyniadakis      216.0
# 112337          Hamed Haddadi      218.0
# 118663         Timofey Mozgov      216.0
# 118676        Dmitry Musersky      219.0
# 120266           Zhang Zhaoxu      221.0
# 121694            Salah Mejri      216.0
# 123850         Tyson Chandler      216.0
# 130460               Li Muhao      218.0
# 130461                Zhou Qi      217.0
# 138671          Ondřej Balvín      216.0
# 139365         Moustapha Fall      218.0

# %%
bios[(bios['height_cm'] > 215) & (bios['born_country'] == 'USA')]
# Out:
#         athlete_id              name   born_date  born_city     born_region  \
# 5781          5804    Tommy Burleson  1952-02-24  Crossnore  North Carolina
# 6722          6755  Shaquille O'Neal  1972-03-06     Newark      New Jersey
# 6937          6972    David Robinson  1965-08-06   Key West         Florida
# 123850      126093    Tyson Chandler  1982-10-02    Hanford      California
#
#        born_country            NOC  height_cm  weight_kg died_date
# 5781            USA  United States      223.0      102.0       NaN
# 6722            USA  United States      216.0      137.0       NaN
# 6937            USA  United States      216.0      107.0       NaN
# 123850          USA  United States      216.0      107.0       NaN

# %%
bios[bios['born_country'].str.contains('USA|',case=False)] # we can access the data with column name and the word
# Out:
#         athlete_id                     name   born_date             born_city  \
# 1670          1677             Freddy Rojas  1969-08-27              Camagüey
# 4001          4015               Ando Reddy  1933-01-18                Dublin
# 4002          4016              Tommy Reddy  1929-07-23                   NaN
# 15322        15427          Freddy Maertens  1952-02-13          Lombardsijde
# 17530        17650           Freddy Cattoir  1906-10-27               Ixelles
# 17592        17712              Freddy Rens  1936-12-25  Bruxelles (Brussels)
# 19501        19640              Freddy Vias  1929-10-08              Seremban
# 22154        22318            Freddy Scholz  1961-09-14            Düsseldorf
# 23655        23839          Freddy Quintero  1938-05-24               Caracas
# 23657        23841           Freddy Salazar  1949-04-11               Caracas
# 25000        25190               Freddy Zix  1935-01-07            Strasbourg
# 29426        29646            Freddy Jensen  1926-01-28                  Nuuk
# 51844        52206            Freddy Brooks  1969-08-10            Guantánamo
# 61463        61912          Freddy Ehrström  1925-08-29              Helsinki
# 64723        65211          Freddy Herbrand  1944-06-01               Malmedy
# 82816        83473            Freddy Mayola  1977-11-01    La Habana (Havana)
# 90682        91405            Freddy Suárez  1971-10-20                Güines
# 91388        92117          Freddy Mansveld  1911-08-02                   NaN
# 94637        95404             Freddy Mésot  1905-05-25          Sint-Niklaas
# 96158        96933            Freddy Romano  1966-07-25                  Bern
# 97116        97898            Freddy Streun  1925-06-17                  Bern
# 100478      101328     Freddy Schwienbacher  1975-08-03                Merano
# 108403      109554          Freddy González  1977-07-10                Cumaná
# 110096      111304               Freddy Adu  1989-06-02                  Tema
# 113059      114348            Freddy Cedeño  1981-09-10               Caracas
# 130801      133549          Freddy Figueroa  1994-11-26             Guayaquil
# 131620      134434         B. Sumeeth Reddy  1991-09-26                Gungal
# 133499      136438           Freddy Mezones  1987-09-24               Caracas
# 140259      143762  Satwiksairaj Rankireddy  2000-08-13                   NaN
#
#                          born_region born_country            NOC  height_cm  \
# 1670                        Camagüey          CUB           Cuba      192.0
# 4001                          Dublin          IRL        Ireland      155.0
# 4002                             NaN          NaN        Ireland        NaN
# 15322                West-Vlaanderen          BEL        Belgium      174.0
# 17530   Région de Bruxelles-Capitale          BEL        Belgium        NaN
# 17592   Région de Bruxelles-Capitale          BEL        Belgium      178.0
# 19501                Negeri Sembilan          MAS         Malaya        NaN
# 22154            Nordrhein-Westfalen          GER   West Germany      183.0
# 23655               Distrito Capital          VEN      Venezuela      170.0
# 23657               Distrito Capital          VEN      Venezuela      175.0
# 25000                       Bas-Rhin          FRA         France      178.0
# 29426                     Sermersooq          GRL        Denmark        NaN
# 51844                     Guantánamo          CUB           Cuba      187.0
# 61463                        Uusimaa          FIN        Finland      178.0
# 64723                          Liège          BEL        Belgium      190.0
# 82816            Ciudad de La Habana          CUB           Cuba      176.0
# 90682                      Mayabeque          CUB           Cuba      178.0
# 91388                            NaN          NaN        Belgium        NaN
# 94637                Oost-Vlaanderen          BEL        Belgium      174.0
# 96158                           Bern          SUI          Italy      178.0
# 97116                           Bern          SUI    Switzerland        NaN
# 100478                 Bolzano-Bozen          ITA          Italy      181.0
# 108403                         Sucre          VEN      Venezuela      160.0
# 110096                 Greater Accra          GHA  United States      170.0
# 113059              Distrito Capital          VEN      Venezuela      205.0
# 130801                        Guayas          ECU        Ecuador      192.0
# 131620                Andhra Pradesh          IND          India      182.0
# 133499              Distrito Capital          VEN      Venezuela      170.0
# 140259                           NaN          NaN          India        NaN
#
#         weight_kg   died_date
# 1670         81.0         NaN
# 4001         58.0  2022-03-06
# 4002          NaN  1992-05-27
# 15322        71.0         NaN
# 17530         NaN  1984-02-16
# 17592        70.0         NaN
# 19501         NaN  2022-06-07
# 22154        74.0         NaN
# 23655        68.0         NaN
# 23657        75.0         NaN
# 25000        76.0         NaN
# 29426         NaN  1996-04-09
# 51844        84.0         NaN
# 61463        70.0         NaN
# 64723        88.0         NaN
# 82816        74.0         NaN
# 90682        75.0         NaN
# 91388         NaN         NaN
# 94637         NaN  1979-10-31
# 96158        70.0         NaN
# 97116         NaN  2019-11-26
# 100478       77.0         NaN
# 108403       60.0         NaN
# 110096       66.0         NaN
# 113059       95.0         NaN
# 130801      100.0         NaN
# 131620       64.0         NaN
# 133499       68.0         NaN
# 140259        NaN         NaN
